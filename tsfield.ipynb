# %%
import astropy
from astropy.io import fits

# %%
hdulist = fits.open('tsField-001659-6-1-0025.fit')

# %%
hdulist

# %%
hdulist.info()
# Out:
# Filename: tsField-001659-6-1-0025.fit
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      30   ()
# 1                BinTableHDU    241   1R x 98C     [1J, 1J, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 1J, 5J, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 1J, 5E, 5E, 1J, 1J, 1J, 1J, 5J, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5J, 5J, 5J, 5E, 5E, 5E, 5E, 1J, 5J, 5E, 5E, 5E, 5E, 5E, 5E, 5J, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5E, 5J, 75E, 75E, 75E, 5E, 5E, 1E, 1E, 1J, 1J, 1J, 1J, 1J]

# %%
tbdata = hdulist[1].data

# %%
tbdata
# Out:
# FITS_rec([ (25, 2, array([ 309.23110815,  309.23036254,  309.23160092,  309.23129477,
#         309.23080717]), array([ 0.00010998,  0.00010999,  0.00010998,  0.00010998,  0.00010998]), array([  3.37731353e-08,   1.95526595e-08,   8.42410622e-09,
#          1.61762433e-08,  -1.13274681e-08]), array([ 1.03886535,  1.03925114,  1.03941506,  1.03916183,  1.03930679]), array([  1.74784755e-10,   1.09569954e-08,  -1.36646984e-08,
#         -3.71524173e-09,  -4.40701805e-09]), array([ 0.00011003,  0.00010996,  0.00010999,  0.00011004,  0.00011   ]), array([-0.01065045,  0.01628794, -0.03805231, -0.0149487 , -0.0250131 ]), array([ -1.52929966e-05,  -5.75622719e-05,   9.02688432e-05,
#          2.77784219e-05,   7.63039983e-05]), array([  7.04462186e-08,   4.80241726e-08,  -6.88457358e-09,
#          6.68638729e-09,  -4.90971459e-08]), array([ -3.41846608e-11,  -1.10983709e-11,  -2.22100204e-11,
# ...

# %%
aa = tbdata.aa
kk = tbdata.kk
airmass = tbdata.airmass

# %%
aa
# Out:
# array([[-23.48469925, -24.42169952, -23.98360062, -23.64360046,
#         -21.84790039]], dtype=float32)

# %%
kk
# Out:
# array([[ 0.50510103,  0.22169501,  0.089756  ,  0.078281  ,  0.0894637 ]], dtype=float32)

# %%
airmass
# Out:
# array([[ 1.25881205,  1.25790157,  1.25986123,  1.25931997,  1.25833877]])
